# %% [markdown]
# CHARGEMENT DES DOSSIERS CSV
#
# Utilisation de pandas

# %%
import pandas as pd
df = pd.read_csv("immo.csv")
df.head()
# Out:
#        id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# 0   107.0  129.0           70.0          1.0        2.0   periurbain
# 1  5484.0  210.0           69.0          5.0        2.0       urbain
# 2  6998.0  397.0          223.0          2.0        2.0       urbain
# 3  3984.0  221.0          185.0          1.0        NaN       urbain
# 4  3111.0   80.0            NaN          2.0        1.0   periurbain
#
#   acces_route eau_electricite type_connexion parking   type_sol etat_maison  \
# 0           0             non          fibre       1     ciment        neuf
# 1         Yes             non       starlink       1       brut         bon
# 2           1               0         aucune     oui  carrelage         bon
# 3         non              No       starlink     non     ciment   a_renover
# 4         oui             oui          fibre     non       brut   a_renover
#
#    annee_construction
# 0              1992.0
# 1              2003.0
# 2              1998.0
# 3              2015.0
# 4              2007.0

# %% [markdown]
# COMPTER LIGNES

# %%
len(df)
# Out:
# 10000

# %% [markdown]
# VERIFICATION DES VALEURS MANQUANTES

# %%
df.isnull().sum()
# Out:
# id                    508
# prix                  504
# superficie_m2         493
# nb_chambres           493
# nb_etages             512
# localisation          504
# acces_route           505
# eau_electricite       491
# type_connexion        508
# parking               512
# type_sol              498
# etat_maison           514
# annee_construction    501
# dtype: int64

# %% [markdown]
#  VERIFIACATION DES DOUBLONS

# %%
df.duplicated(subset=['id']).sum()
# Out:
# np.int64(1286)

# %% [markdown]
# AFFICHER

# %%
df[df.duplicated(subset=['id'], keep=False)]
# Out:
#           id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# 6     3013.0  273.0          222.0          5.0        1.0        rural
# 19    5226.0  220.0          171.0          2.0        2.0          NaN
# 20    3088.0  314.0          243.0          3.0        2.0       urbain
# 21       NaN  404.0          156.0          1.0        NaN       urbain
# 25     381.0   97.0           81.0          1.0        NaN   periurbain
# ...      ...    ...            ...          ...        ...          ...
# 9980  9099.0  130.0           54.0          5.0        1.0       urbain
# 9984  3778.0  112.0          117.0          3.0        1.0   periurbain
# 9993   950.0  338.0          239.0          5.0        NaN          NaN
# 9996   419.0  313.0          183.0          1.0        1.0       urbain
# 9999     NaN   86.0           55.0          5.0        2.0   periurbain
#
#      acces_route eau_electricite type_connexion parking   type_sol  \
# 6              0             oui       starlink      No  carrelage
# 19            No             NaN         aucune     non  carrelage
# 20           NaN              No       starlink     non     ciment
# 21           oui             Yes         aucune     oui     ciment
# 25             0              No         aucune     non       brut
# ...          ...             ...            ...     ...        ...
# 9980           0             Yes       starlink      No        NaN
# 9984           1             non         aucune     Yes  carrelage
# 9993         Yes               0         aucune      No  carrelage
# 9996          No             Yes          fibre     Yes  carrelage
# 9999         Yes               0          fibre      No     ciment
#
#      etat_maison  annee_construction
# 6           neuf              1997.0
# 19     a_renover              2015.0
# 20     a_renover              2014.0
# 21          neuf              2012.0
# 25           bon              2016.0
# ...          ...                 ...
# 9980   a_renover                 NaN
# 9984   a_renover                 NaN
# 9993   a_renover              2008.0
# 9996         bon              1990.0
# 9999   a_renover              2017.0
#
# [2066 rows x 13 columns]

# %% [markdown]
# NETTOYAGE
#
# 1 : Suppression des valeurs manquantes
#
# 2 : Suppression des doublons

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %% [markdown]
# DEUXIEME VERIFICATION MANQUANTES ET DOUBLONS

# %%
df.isnull().sum()
# Out:
# id                    0
# prix                  0
# superficie_m2         0
# nb_chambres           0
# nb_etages             0
# localisation          0
# acces_route           0
# eau_electricite       0
# type_connexion        0
# parking               0
# type_sol              0
# etat_maison           0
# annee_construction    0
# dtype: int64

# %%
df.duplicated(subset=['id']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# AFFICHAGE DES TOUS LES COLLONNES UTILISEES

# %%
print(df.columns)
# Out:
# Index(['id', 'prix', 'superficie_m2', 'nb_chambres', 'nb_etages',
#        'localisation', 'acces_route', 'eau_electricite', 'type_connexion',
#        'parking', 'type_sol', 'etat_maison', 'annee_construction'],
#       dtype='object')

# %%
print(list(df.columns))
# Out:
# ['id', 'prix', 'superficie_m2', 'nb_chambres', 'nb_etages', 'localisation', 'acces_route', 'eau_electricite', 'type_connexion', 'parking', 'type_sol', 'etat_maison', 'annee_construction']

# %%
for col in df.columns:
    print(col)
# Out:
# id
# prix
# superficie_m2
# nb_chambres
# nb_etages
# localisation
# acces_route
# eau_electricite
# type_connexion
# parking
# type_sol
# etat_maison
# annee_construction

# %% [markdown]
# ETAPE 4 : INFORMATIONS DE TYPES DES COLONNES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4745 entries, 0 to 9998
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4745 non-null   float64
#  1   prix                4745 non-null   float64
#  2   superficie_m2       4745 non-null   float64
#  3   nb_chambres         4745 non-null   float64
#  4   nb_etages           4745 non-null   float64
#  5   localisation        4745 non-null   object
#  6   acces_route         4745 non-null   object
#  7   eau_electricite     4745 non-null   object
#  8   type_connexion      4745 non-null   object
#  9   parking             4745 non-null   object
#  10  type_sol            4745 non-null   object
#  11  etat_maison         4745 non-null   object
#  12  annee_construction  4745 non-null   float64
# dtypes: float64(6), object(7)
# memory usage: 519.0+ KB

# %% [markdown]
# ETAPE 5 : INSPECTION DES TYPES OBJETS

# %%
obj_cols = df.select_dtypes(include='object')

print(obj_cols.columns)
# Out:
# Index(['localisation', 'acces_route', 'eau_electricite', 'type_connexion',
#        'parking', 'type_sol', 'etat_maison'],
#       dtype='object')

# %%
for col in obj_cols.columns:
    print(f"Colonne: {col}")
    print(df[col].unique())
# Out:
# Colonne: localisation
# ['periurbain' 'urbain' 'rural']
# Colonne: acces_route
# ['0' 'Yes' '1' 'non' 'No' 'oui']
# Colonne: eau_electricite
# ['non' '0' 'oui' '1' 'No' 'Yes']
# Colonne: type_connexion
# ['fibre' 'starlink' 'aucune']
# Colonne: parking
# ['1' 'oui' 'Yes' 'No' '0' 'non']
# Colonne: type_sol
# ['ciment' 'brut' 'carrelage']
# Colonne: etat_maison
# ['neuf' 'bon' 'a_renover']

# %%
for col in obj_cols.columns:
    print(f"{col} → {df[col].nunique()} valeurs uniques")
# Out:
# localisation → 3 valeurs uniques
# acces_route → 6 valeurs uniques
# eau_electricite → 6 valeurs uniques
# type_connexion → 3 valeurs uniques
# parking → 6 valeurs uniques
# type_sol → 3 valeurs uniques
# etat_maison → 3 valeurs uniques

# %% [markdown]
# NETTOYAGE PAR TYPE

# %% [markdown]
# UNIFORMISATION

# %%
df['acces_route'] = df['acces_route'].str.strip().str.lower()

# %%
df['eau_electricite'] = df['eau_electricite'].str.strip().str.lower()

# %%
df['parking'] = df['parking'].str.strip().str.lower()

# %%
df['type_sol'] = df['type_sol'].str.strip().str.lower()

# %%
df['etat_maison'] = df['etat_maison'].str.strip().str.lower()

# %%
df['type_connexion'] = df['type_connexion'].str.strip().str.lower()

# %%
df['localisation'] = df['localisation'].str.strip().str.lower()

# %% [markdown]
# TYPE OBJETS

# %% [markdown]
# CREATION MAPPING

# %%
mapping = {
    '0': False,
    'no': False,
    'non': False,
    '1': True,
    'yes': True,
    'oui': True
}

# %% [markdown]
# ACCES ROUTE

# %% [markdown]
# APPLICATION DE LA TRANSFORMATION

# %%
df['acces_route'] = df['acces_route'].map(mapping)

# %% [markdown]
# DEUXIEME VERIFICATIONS

# %%
for col in obj_cols.columns:
    print(f"Colonne: {col}")
    print(df[col].unique())
# Out:
# Colonne: localisation
# ['periurbain' 'urbain' 'rural']
# Colonne: acces_route
# [False  True]
# Colonne: eau_electricite
# ['non' '0' 'oui' '1' 'no' 'yes']
# Colonne: type_connexion
# ['fibre' 'starlink' 'aucune']
# Colonne: parking
# ['1' 'oui' 'yes' 'no' '0' 'non']
# Colonne: type_sol
# ['ciment' 'brut' 'carrelage']
# Colonne: etat_maison
# ['neuf' 'bon' 'a_renover']

# %%
print(df['acces_route'].unique())
print(df['acces_route'].dtype)
# Out:
# [False  True]
# bool

# %% [markdown]
# EAU ET ELECTRICITE

# %%
df['eau_electricite'] = df['eau_electricite'].map(mapping)

# %%
for col in obj_cols.columns:
    print(f"Colonne: {col}")
    print(df[col].unique())
# Out:
# Colonne: localisation
# ['periurbain' 'urbain' 'rural']
# Colonne: acces_route
# [False  True]
# Colonne: eau_electricite
# [False  True]
# Colonne: type_connexion
# ['fibre' 'starlink' 'aucune']
# Colonne: parking
# ['1' 'oui' 'yes' 'no' '0' 'non']
# Colonne: type_sol
# ['ciment' 'brut' 'carrelage']
# Colonne: etat_maison
# ['neuf' 'bon' 'a_renover']

# %% [markdown]
# PARKING

# %%
df['parking'] = df['parking'].map(mapping)

# %%
for col in obj_cols.columns:
    print(f"Colonne: {col}")
    print(df[col].unique())
# Out:
# Colonne: localisation
# ['periurbain' 'urbain' 'rural']
# Colonne: acces_route
# [False  True]
# Colonne: eau_electricite
# [False  True]
# Colonne: type_connexion
# ['fibre' 'starlink' 'aucune']
# Colonne: parking
# [ True False]
# Colonne: type_sol
# ['ciment' 'brut' 'carrelage']
# Colonne: etat_maison
# ['neuf' 'bon' 'a_renover']

# %% [markdown]
# VERIFICATION DES VALEURS

# %% [markdown]
# VALEURS NEGATIVES

# %%
cols = ['prix', 'superficie_m2', 'nb_chambres', 'nb_etages']

for col in cols:
    print(col, (df[col] < 0).sum())
# Out:
# prix 0
# superficie_m2 0
# nb_chambres 0
# nb_etages 0

# %% [markdown]
# VOIR DES LIGNES CHOISI

# %% [markdown]
# PREMIER LIGNE

# %%
df.head(30)
# Out:
#         id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# 0    107.0  129.0           70.0          1.0        2.0   periurbain
# 1   5484.0  210.0           69.0          5.0        2.0       urbain
# 2   6998.0  397.0          223.0          2.0        2.0       urbain
# 5   4040.0  135.0           67.0          5.0        1.0   periurbain
# 6   3013.0  273.0          222.0          5.0        1.0        rural
# 7   6607.0  194.0           71.0          4.0        2.0       urbain
# 8   4219.0   91.0          105.0          3.0        2.0        rural
# 10  5665.0  114.0          106.0          1.0        2.0        rural
# 11  9225.0   47.0           61.0          1.0        1.0        rural
# 12  8030.0  277.0          229.0          3.0        1.0   periurbain
# 14  1851.0  362.0          207.0          2.0        1.0   periurbain
# 16  3043.0  185.0           53.0          5.0        2.0       urbain
# 17  3369.0  147.0          116.0          2.0        2.0   periurbain
# 18  6829.0  383.0          202.0          3.0        2.0       urbain
# 23  4993.0  545.0          202.0          2.0        1.0       urbain
# 24  4209.0  189.0          157.0          2.0        1.0   periurbain
# 30  8412.0  370.0          175.0          5.0        2.0   periurbain
# 36  5938.0  101.0           72.0          2.0        1.0   periurbain
# 40  4786.0  439.0          244.0          3.0        1.0   periurbain
# 41  2602.0  301.0          227.0          5.0        2.0   periurbain
# 42  7779.0   90.0          128.0          1.0        1.0        rural
# 43  2826.0  143.0          172.0          2.0        2.0   periurbain
# 44  1118.0  392.0          220.0          2.0        2.0       urbain
# 47  8654.0  307.0          103.0          2.0        2.0       urbain
# 48  7719.0  212.0          141.0          5.0        1.0   periurbain
# 49  6575.0  273.0          181.0          5.0        2.0       urbain
# 51  7234.0  424.0          114.0          5.0        2.0       urbain
# 52  8366.0  207.0           70.0          5.0        1.0   periurbain
# 53  3948.0  110.0           93.0          1.0        2.0   periurbain
# 57  2820.0  115.0           86.0          2.0        1.0   periurbain
#
#     acces_route  eau_electricite type_connexion  parking   type_sol  \
# 0         False            False          fibre     True     ciment
# 1          True            False       starlink     True       brut
# 2          True            False         aucune     True  carrelage
# 5         False            False          fibre     True  carrelage
# 6         False             True       starlink    False  carrelage
# 7         False             True       starlink    False     ciment
# 8         False            False       starlink    False       brut
# 10        False            False       starlink    False     ciment
# 11        False             True       starlink     True       brut
# 12        False            False         aucune    False     ciment
# 14        False            False         aucune     True       brut
# 16         True            False         aucune     True     ciment
# 17        False             True         aucune     True  carrelage
# 18         True             True         aucune    False       brut
# 23         True            False          fibre    False       brut
# 24         True             True         aucune     True     ciment
# 30         True             True       starlink    False     ciment
# 36         True             True          fibre    False     ciment
# 40         True            False         aucune     True     ciment
# 41         True             True          fibre     True       brut
# 42        False            False         aucune    False     ciment
# 43        False            False          fibre    False       brut
# 44        False             True          fibre    False     ciment
# 47         True             True         aucune     True  carrelage
# 48        False            False          fibre     True     ciment
# 49        False            False          fibre    False       brut
# 51        False             True       starlink     True       brut
# 52        False            False          fibre    False  carrelage
# 53         True            False          fibre    False  carrelage
# 57        False            False         aucune    False       brut
#
#    etat_maison  annee_construction
# 0         neuf              1992.0
# 1          bon              2003.0
# 2          bon              1998.0
# 5          bon              2013.0
# 6         neuf              1997.0
# 7          bon              2022.0
# 8          bon              2002.0
# 10        neuf              2004.0
# 11         bon              2008.0
# 12         bon              2000.0
# 14        neuf              1995.0
# 16         bon              2023.0
# 17         bon              1993.0
# 18         bon              1994.0
# 23        neuf              2022.0
# 24         bon              1998.0
# 30        neuf              1995.0
# 36         bon              2009.0
# 40        neuf              2005.0
# 41         bon              2006.0
# 42         bon              1991.0
# 43   a_renover              1990.0
# 44         bon              2020.0
# 47        neuf              2006.0
# 48         bon              1992.0
# 49   a_renover              1991.0
# 51        neuf              2018.0
# 52        neuf              1995.0
# 53         bon              2013.0
# 57         bon              1990.0

# %% [markdown]
# DERNIER LIGNE

# %%
df.tail(20)
# Out:
#           id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# 9961  9831.0   96.0          201.0          1.0        1.0        rural
# 9962  7790.0  149.0          108.0          2.0        2.0       urbain
# 9964  7783.0   89.0          174.0          2.0        2.0        rural
# 9965  2443.0  179.0          110.0          5.0        1.0   periurbain
# 9968   814.0  128.0          163.0          3.0        1.0        rural
# 9969  6166.0   97.0          101.0          4.0        2.0        rural
# 9970  5779.0  278.0          211.0          3.0        2.0       urbain
# 9972   793.0  190.0          235.0          5.0        2.0        rural
# 9973  6898.0   82.0          159.0          2.0        2.0        rural
# 9978  2891.0  297.0          240.0          2.0        1.0       urbain
# 9979  2371.0  232.0          195.0          1.0        1.0       urbain
# 9983  6359.0  410.0          200.0          5.0        2.0   periurbain
# 9987  1865.0  144.0           67.0          2.0        1.0   periurbain
# 9988  4612.0  125.0           55.0          2.0        1.0   periurbain
# 9990  2243.0   99.0          196.0          2.0        2.0        rural
# 9991  5373.0  209.0          149.0          3.0        2.0       urbain
# 9992  2336.0   80.0          129.0          4.0        1.0        rural
# 9995  2204.0  222.0          163.0          4.0        2.0   periurbain
# 9997   922.0  356.0          210.0          1.0        2.0       urbain
# 9998  9446.0   75.0          104.0          5.0        2.0        rural
#
#       acces_route  eau_electricite type_connexion  parking   type_sol  \
# 9961        False            False       starlink     True  carrelage
# 9962         True             True         aucune     True     ciment
# 9964         True            False          fibre    False  carrelage
# 9965        False            False          fibre     True  carrelage
# 9968        False             True         aucune    False       brut
# 9969        False             True          fibre    False     ciment
# 9970         True            False         aucune    False     ciment
# 9972        False             True          fibre     True  carrelage
# 9973         True            False          fibre     True  carrelage
# 9978         True             True       starlink    False       brut
# 9979         True            False          fibre    False     ciment
# 9983         True             True         aucune     True       brut
# 9987        False             True         aucune     True       brut
# 9988         True            False         aucune     True  carrelage
# 9990        False            False       starlink    False  carrelage
# 9991        False             True       starlink    False  carrelage
# 9992        False             True          fibre    False       brut
# 9995        False             True         aucune    False       brut
# 9997        False            False          fibre    False       brut
# 9998         True            False         aucune     True  carrelage
#
#      etat_maison  annee_construction
# 9961   a_renover              2004.0
# 9962   a_renover              1999.0
# 9964   a_renover              1990.0
# 9965         bon              2005.0
# 9968         bon              2018.0
# 9969         bon              2019.0
# 9970   a_renover              1992.0
# 9972         bon              2004.0
# 9973   a_renover              2003.0
# 9978   a_renover              1994.0
# 9979   a_renover              2012.0
# 9983        neuf              2018.0
# 9987        neuf              1992.0
# 9988        neuf              2010.0
# 9990   a_renover              1990.0
# 9991   a_renover              2005.0
# 9992   a_renover              1998.0
# 9995         bon              2008.0
# 9997         bon              2008.0
# 9998   a_renover              2021.0

# %% [markdown]
# ALEATOIRES

# %%
df.sample(10)
# Out:
#           id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# 1280   465.0   93.0          115.0          1.0        1.0   periurbain
# 5497  1876.0  312.0          150.0          4.0        2.0   periurbain
# 118   2492.0  113.0           80.0          3.0        2.0        rural
# 1108  2357.0  105.0           97.0          1.0        1.0        rural
# 398   9679.0   90.0          175.0          2.0        1.0        rural
# 9546  2396.0  105.0           51.0          4.0        2.0   periurbain
# 8646  8964.0  342.0          157.0          5.0        1.0   periurbain
# 1356    92.0  112.0          142.0          1.0        1.0   periurbain
# 9647  9323.0  637.0          203.0          5.0        1.0       urbain
# 4370  1480.0   82.0          132.0          4.0        1.0        rural
#
#       acces_route  eau_electricite type_connexion  parking   type_sol  \
# 1280        False             True       starlink    False       brut
# 5497        False             True       starlink     True       brut
# 118         False             True          fibre     True       brut
# 1108         True             True         aucune     True     ciment
# 398         False            False         aucune     True     ciment
# 9546         True            False         aucune     True  carrelage
# 8646         True             True          fibre     True  carrelage
# 1356         True            False          fibre     True     ciment
# 9647        False            False          fibre    False     ciment
# 4370         True            False       starlink     True     ciment
#
#      etat_maison  annee_construction
# 1280   a_renover              1991.0
# 5497        neuf              1992.0
# 118         neuf              2018.0
# 1108        neuf              2016.0
# 398    a_renover              2002.0
# 9546         bon              1998.0
# 8646        neuf              1999.0
# 1356   a_renover              2017.0
# 9647        neuf              2011.0
# 4370   a_renover              1995.0

# %% [markdown]
# COMPTER LIGNES

# %% [markdown]
# EVALUATION

# %%
len(df)
# Out:
# 4745

# %%
df.describe()
# Out:
#                 id         prix  superficie_m2  nb_chambres    nb_etages  \
# count  4745.000000  4745.000000    4745.000000  4745.000000  4745.000000
# mean   5007.845522   218.264489     148.984615     2.967756     1.490832
# std    2880.406750   133.690155      58.288891     1.425945     0.499969
# min       0.000000    31.000000      50.000000     1.000000     1.000000
# 25%    2515.000000   118.000000      98.000000     2.000000     1.000000
# 50%    5006.000000   186.000000     149.000000     3.000000     1.000000
# 75%    7520.000000   283.000000     200.000000     4.000000     2.000000
# max    9995.000000   748.000000     249.000000     5.000000     2.000000
#
#        annee_construction
# count         4745.000000
# mean          2006.581665
# std              9.896605
# min           1990.000000
# 25%           1998.000000
# 50%           2007.000000
# 75%           2015.000000
# max           2023.000000

# %% [markdown]
# AFFICHAGE MIN ET MAX

# %%
df.agg(['min', 'max'])
# Out:
#          id   prix  superficie_m2  nb_chambres  nb_etages localisation  \
# min     0.0   31.0           50.0          1.0        1.0   periurbain
# max  9995.0  748.0          249.0          5.0        2.0       urbain
#
#      acces_route  eau_electricite type_connexion  parking type_sol  \
# min        False            False         aucune    False     brut
# max         True             True       starlink     True   ciment
#
#     etat_maison  annee_construction
# min   a_renover              1990.0
# max        neuf              2023.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4745 entries, 0 to 9998
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4745 non-null   float64
#  1   prix                4745 non-null   float64
#  2   superficie_m2       4745 non-null   float64
#  3   nb_chambres         4745 non-null   float64
#  4   nb_etages           4745 non-null   float64
#  5   localisation        4745 non-null   object
#  6   acces_route         4745 non-null   bool
#  7   eau_electricite     4745 non-null   bool
#  8   type_connexion      4745 non-null   object
#  9   parking             4745 non-null   bool
#  10  type_sol            4745 non-null   object
#  11  etat_maison         4745 non-null   object
#  12  annee_construction  4745 non-null   float64
# dtypes: bool(3), float64(6), object(4)
# memory usage: 421.7+ KB

# %% [markdown]
# MODIFICATIONS DE TYPES
#
# On change les types des colonnes pour avoir des normes et logiques des données

# %%
df['localisation'] = df['localisation'].astype('category')

# %%
df['type_connexion'] = df['type_connexion'].astype('category')

# %%
df['type_sol'] = df['type_sol'].astype('category')

# %%
df['etat_maison'] = df['etat_maison'].astype('category')

# %%
df['prix'] = df['prix'].astype('int')

# %%
df['nb_chambres'] = df['nb_chambres'].astype('int')

# %%
df['nb_etages'] = df['nb_etages'].astype('int')

# %%
df['id'] = df['id'].astype('int')

# %%
df['id'] = df['id'].astype('int')

# %%
df['annee_construction'] = df['annee_construction'].astype('int')

# %%
print(df['id'].dtype)
# Out:
# int64

# %% [markdown]
# CHANGEMENT DES NOMS D'UN COLONNES
#
# On change le prix  en million d'ariary

# %%
df.rename(columns={'prix': 'prix_million_ariary'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4745 entries, 0 to 9998
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   4745 non-null   int64
#  1   prix_million_ariary  4745 non-null   int64
#  2   superficie_m2        4745 non-null   float64
#  3   nb_chambres          4745 non-null   int64
#  4   nb_etages            4745 non-null   int64
#  5   localisation         4745 non-null   category
#  6   acces_route          4745 non-null   bool
#  7   eau_electricite      4745 non-null   bool
#  8   type_connexion       4745 non-null   category
#  9   parking              4745 non-null   bool
#  10  type_sol             4745 non-null   category
#  11  etat_maison          4745 non-null   category
#  12  annee_construction   4745 non-null   int64
# dtypes: bool(3), category(4), float64(1), int64(5)
# memory usage: 292.4 KB

# %% [markdown]
# SAUVEGARDE FICHIER NETTOYEE

# %%
df.to_csv('immobilier_nettoye.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
